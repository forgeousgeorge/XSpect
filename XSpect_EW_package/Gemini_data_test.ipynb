# %%
from pathlib import Path #Allows for easy path conversion to any OS
from XSpect_EW_class import *
from XSpect_EW_func import *
# Out:
# Working

# %%
Hebe_x = np.load('Hebe_x.npy')
Hebe_y = np.load('Hebe_y.npy')

# %%
order = 30
plt.plot(Hebe_x[order], Hebe_y[order])
plt.show()

# %%
Hebe = Spectrum_Data('Hebe_solar', KECK_file = False, spectx = Hebe_x, specty = Hebe_y)

# %%
wasp_x = np.load("/Users/georgevejar/Downloads/Gemini2020B/WASP_77A_x.npy", allow_pickle=True)
wasp_y = np.load("/Users/georgevejar/Downloads/Gemini2020B/WASP_77A_y.npy", allow_pickle=True)

# %%
wasp_y
# Out:
# array([array([  0.66556174,   0.6440973 ,   0.7249661 , ...,   0.7506441 ,
#          0.74858683, 106.985     ], dtype=float32),
#        array([  0.5464364 ,   0.55459934,   0.62817293, ...,   0.7024435 ,
#          0.6879534 , 216.545     ], dtype=float32),
#        array([  0.5057757,   0.526542 ,   0.5573061, ...,   0.425779 ,
#          0.3351614, 215.779    ], dtype=float32),
#        array([ 0.58289397,  0.64749694,  0.6381965 , ...,  0.5101825 ,
#         0.5416755 , 98.7489    ], dtype=float32),
#        array([4.9186045e-01, 5.8103192e-01, 6.6038221e-01, ..., 8.7236351e-01,
#        8.8488996e-01, 7.2782098e+02], dtype=float32),
#        array([4.7313419e-01, 4.5980501e-01, 4.5239782e-01, ..., 5.7263875e-01,
#        6.3260543e-01, 1.1067600e+03], dtype=float32),
#        array([2.4118060e-01, 2.4898288e-01, 2.6735750e-01, ..., 6.4440644e-01,
#        6.3408190e-01, 1.3588400e+03], dtype=float32),
# ...

# %%
WASP_77A = Spectrum_Data('WASP_77A', KECK_file = False, spectx = wasp_x, specty = wasp_y)

# %%
# %matplotlib inline
order = 20
plt.plot(WASP_77A.wavelength[order], WASP_77A.flux[order])
plt.plot(WASP_77A.wavelength[order], WASP_77A.normalized_flux[order])

# %%
# %%time
window_width = 1.6 
depth = 90
Hebe.normalize_all(window_width=window_width, continuum_depth=depth)
# Out:
# /Users/georgevejar/Documents/GitHub/XSpect/XSpect-EW/XSpect_EW_class.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   err_est = self.obs_err[i]/self.pred_all[i]
# /Users/georgevejar/Documents/GitHub/XSpect/XSpect-EW/XSpect_EW_class.py:115: RuntimeWarning: invalid value encountered in true_divide
#   err_est = self.obs_err[i]/self.pred_all[i]
# /Users/georgevejar/Documents/GitHub/XSpect/XSpect-EW/XSpect_EW_class.py:115: RuntimeWarning: invalid value encountered in true_divide
#   err_est = self.obs_err[i]/self.pred_all[i]
# /Users/georgevejar/Documents/GitHub/XSpect/XSpect-EW/XSpect_EW_class.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   err_est = self.obs_err[i]/self.pred_all[i]
# /Users/georgevejar/Documents/GitHub/XSpect/XSpect-EW/XSpect_EW_class.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   err_est = self.obs_err[i]/self.pred_all[i]
# ...

# %%
# %%time
window_width = 0.8
depth = 90
WASP_77A.normalize_all(window_width=window_width, continuum_depth=depth)
# Out:
# /Users/georgevejar/Documents/GitHub/XSpect/XSpect-EW/XSpect_EW_class.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   err_est = self.obs_err[i]/self.pred_all[i]
# /Users/georgevejar/Documents/GitHub/XSpect/XSpect-EW/XSpect_EW_class.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   err_est = self.obs_err[i]/self.pred_all[i]
# /Users/georgevejar/Documents/GitHub/XSpect/XSpect-EW/XSpect_EW_class.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   err_est = self.obs_err[i]/self.pred_all[i]
# /Users/georgevejar/Documents/GitHub/XSpect/XSpect-EW/XSpect_EW_class.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   err_est = self.obs_err[i]/self.pred_all[i]
# CPU times: user 55.2 s, sys: 3.11 s, total: 58.3 s
# Wall time: 33.8 s
# /Users/georgevejar/Documents/GitHub/XSpect/XSpect-EW/XSpect_EW_class.py:115: RuntimeWarning: divide by zero encountered in true_divide
#   err_est = self.obs_err[i]/self.pred_all[i]

# %%
# %matplotlib notebook
Hebe.check_spectra() #0.8 Ang
# Out:
# <img src="data:image/png;base64,..." width="574.4444596620258">

# %%
# %matplotlib notebook
WASP_77A.check_spectra() #0.08 nm
# Out:
# <img src="data:image/png;base64,..." width="982.2222482422259">

# %%
order = 
plt.plot(Hebe.wavelength[order], Hebe.normalized_flux[order])
plt.plot(Hebe.wavelength[order], Hebe.flux[order])
plt.ylim([0.2,1.1])
plt.show()

# %%
# %matplotlib 
order = 15
plt.plot(WASP_77A.wavelength[order], WASP_77A.normalized_flux[order])
plt.plot(WASP_77A.wavelength[order], WASP_77A.flux[order])
plt.ylim([0.2,1.1])
plt.xlim([560,562])
plt.show()
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# %matplotlib inline
order = 19
xlims = [615,640]
ylims = [0,1.2]
fig = plt.figure(figsize=(10,5))
#fig = plt.figure(figsize=(10,5))
counts = fig.add_subplot(211)
counts.plot(WASP_77A.wavelength[order],WASP_77A.flux[order], lw = 0.8, label = 'Gem Data')
counts.plot(WASP_77A.wavelength[order],WASP_77A.pred_all[order], 'k',alpha = 0.5, label = 'GP fit')
# counts.fill_between(WASP_77A.wavelength[order],WASP_77A.m_all[order]+2*np.sqrt(np.diag(WASP_77A.C_all[order])),
#                  WASP_77A.m_all[order]-2*np.sqrt(np.diag(WASP_77A.C_all[order])),color='k',alpha=0.2)
counts.errorbar(WASP_77A.wavelength[order][WASP_77A.continuum[order]],WASP_77A.flux[order][WASP_77A.continuum[order]],
             yerr=WASP_77A.obs_err[order][WASP_77A.continuum[order]],capsize=0,fmt='k.', label = 'Selected Cont')
counts.set_ylabel('Counts')
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))
counts.set_xlim(xlims)
counts.set_ylim(ylims)
counts.set_xticklabels([])
counts.legend(loc='best', prop={'size': 6})
counts.grid()

norm = fig.add_subplot(212)
#norm.errorbar(WASP_77A.wavelength[order],WASP_77A.normalized_flux[order],yerr=WASP_77A.obs_err[order]/WASP_77A.m_all[order])
norm.plot(WASP_77A.wavelength[order],WASP_77A.normalized_flux[order], lw = 0.8, label = 'Gem Data')
norm.set_ylabel('Normalized Flux')
norm.set_xlabel(r'$\rm Wavelength~(\AA)$')
norm.set_xlim(xlims)
norm.set_ylim(ylims)
norm.grid()

plt.tight_layout()
plt.subplots_adjust(hspace = 0)
#plt.savefig('Cont_norm_sample.pdf')

# %% [markdown]
# ## bug: flux array seems to be replaced with the normalized array
#  - Not sure why, check normalization function for insertion of values
#  - check continuum scan class and functions as well

# %% [markdown]
# ## bug: Normalization doesn't seem to be working all that great
#  - try different window sizes and depths
#  - also check code itself for other errors that could be affecting normalization
